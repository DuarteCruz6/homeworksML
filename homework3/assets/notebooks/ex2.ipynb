# %%
import sys
import os
import importlib
import numpy as np

#Add code paths
sys.path.append(os.path.abspath("../code/part2/"))

# %% [markdown]
# # Ex2
# training set (linearly separable):
# - x1 = (-2,-2)T,  x2 = (1,0)T, x3 = (0,1)T
#
# targets:
# - t1=0, t2=0, t3=1
#
# setup:
# - weights = 1, bias = 1, learning rate = 1
#
# learning algorithm:
# - sgn0(x) = 1 if x>=0, 0 if x<0

# %%
bias = 1

x1 = np.array([bias,-2,-2])
x2 = np.array([bias,1,0])
x3 = np.array([bias,0,1])
inputs = np.array([x1,x2,x3])

t1 = 0
t2 = 0
t3 = 1
targets = np.array([t1,t2,t3])

weight = np.transpose(np.array([bias,1,1]))
learning_rate = 1

# %% [markdown]
# ## a) Apply the perceptron learning algorithm for one iteration

# %%
import perceptron as p 
importlib.reload(p) 

p.learn(inputs, targets, weight, learning_rate, num_iterations = 1, debug = False)
# Out:
# Weight after iterations:
#  [[0]
#  [0]
#  [1]]

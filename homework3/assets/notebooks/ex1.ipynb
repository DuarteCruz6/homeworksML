# %%
import sys
import os
import importlib
import numpy as np

#Add code paths
sys.path.append(os.path.abspath("../code/part1/"))

# %% [markdown]
# # Ex1
# training set (1 dimension):
# - x1=1,  x2=0,  x3=-2,  x4=5,  x5=-5
#
# targets:
# - t1=-1, t2=1, t3=-1, t4=0, t5=-1
#
# functions:
# - Φ(x) = x^j
# - y(x,w) = w0 + w1 . x + w2 . x^2 + w3 . x^3

# %%
x1 = 1
x2 = 0
x3 = -2
x4 = 5
x5 = -5

t1 = -1
t2 = 1
t3 = -1
t4 = 0
t5 = -1

training_set = np.array([x1,x2,x3,x4,x5])
targets = np.array([t1,t2,t3,t4,t5])

# %% [markdown]
# ## a) Compute the design matrix Φ.

# %%
import a 
importlib.reload(a) 

design_matrix = a.calculate_design_matrix(training_set, size = 3) #size corresponds to the biggest exponent in function y(x,w)

# %% [markdown]
# ## b) Compute the polynomial regression weights.

# %%
import b 
importlib.reload(b)

b.calculate_regression_weights(design_matrix, targets, debug = False)
# Out:
# RESULT:
#  [[-0.2382047 ]
#  [ 0.11114878]
#  [-0.01273203]
#  [-0.00034768]]

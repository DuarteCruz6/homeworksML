# %% [markdown]
# # H3, Perceptron and NN

# %%
import matplotlib.pyplot as plt
from sklearn import metrics, datasets, tree
from sklearn.model_selection import train_test_split

# 1. load 
dt = datasets.load_digits() 
X, y = dt.data, dt.target

#from sklearn.datasets import fetch_openml
#mnist = fetch_openml('mnist_784')

# partition data with train_test_split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,stratify=y,random_state=42)


print("train size:",len(X_train),"\ntest size:",len(X_test))
# Out:
# train size: 1257
# test size: 540

# %%
# 2. learn classifier
from sklearn.linear_model import LogisticRegression

predictor = LogisticRegression(max_iter=2000) 
predictor.fit(X_train, y_train)

y_pred = predictor.predict(X_test)
print("accuracy on testing set:",  round(metrics.accuracy_score(y_test, y_pred),2))
# Out:
# accuracy on testing set: 0.96

# %%
plt.plot(predictor.loss_curve_)
plt.title("Loss Curve", fontsize=14)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 plt.plot(predictor.loss_curve_)
#       2 plt.title("Loss Curve", fontsize=14)
#       3 plt.xlabel('Iterations')
#
# AttributeError: 'LogisticRegression' object has no attribute 'loss_curve_'

# %% [markdown]
# LogisticRegression in scikit-learn does NOT return the loss values during training, so you cannot directly plot the loss curve the way you can in neural networks.
#
# This is an example of serious limitations of scikit-learn, or sticking to one software framework.
#
# Using PyTorch or TensorFlow allows us to do it, or programming LogisticRegression dierectly in Python.

# %% [markdown]
# hidden_layer_sizes : This parameter allows us to set the number of layers and the number of nodes we wish to have in the Neural Network Classifier. Each element in the tuple represents the number of nodes at the ith position where i is the index of the tuple. Thus the length of tuple denotes the total number of hidden layers in the network.
#
# max_iter: It denotes the number of epochs.

# %%
# 2. learn classifier
from sklearn.neural_network import MLPClassifier

predictor = MLPClassifier(hidden_layer_sizes=(1),random_state=42,activation ='identity',solver='sgd',max_iter=2000)
#predictor = MLPClassifier(random_state=42)
predictor.fit(X_train, y_train)

y_pred = predictor.predict(X_test)
print("accuracy on testing set:",  round(metrics.accuracy_score(y_test, y_pred),4))
# Out:
# accuracy on testing set: 0.3574

# %% [markdown]
# Loss curve plots the training  error (y-axis) over the training set size (x-axis).

# %%
plt.plot(predictor.loss_curve_)
plt.title("Loss Curve", fontsize=14)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()

# %%
# 2. learn classifier
from sklearn.neural_network import MLPClassifier

predictor = MLPClassifier(hidden_layer_sizes=(100,100),random_state=42,activation ='identity',solver='sgd',max_iter=2000)
#predictor = MLPClassifier(random_state=42)
predictor.fit(X_train, y_train)

y_pred = predictor.predict(X_test)
print("accuracy on testing set:",  round(metrics.accuracy_score(y_test, y_pred),4))
# Out:
# accuracy on testing set: 0.9481

# %%
plt.plot(predictor.loss_curve_)
plt.title("Loss Curve", fontsize=14)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()

# %% [markdown]
# Hidden layers of hidden units produce only linear functions and we get the same discrimination power (linear separable) as simple perceptron.

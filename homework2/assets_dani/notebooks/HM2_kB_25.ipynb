# %% [markdown]
# # HM2, kNN versus GaussianNB

# %% [markdown]
# ## 1 Digits Data Set
#
# The data set contains images of hand-written digits: 10 classes where each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract normalized bitmaps of handwritten digits from a preprinted form. From a total of 43 people, 30 contributed to the training set and different 13 to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of 4x4 and the number of on pixels are counted in each block. This generates an input matrix of 8x8 where each element is an integer in the range 0..16. This reduces dimensionality and gives invariance to small distortions.

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics, datasets

# 1. load 
digits = datasets.load_digits()

_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % label)

# %%
X, y = digits.data, digits.target

# partition data with train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,stratify=y,random_state=42)

print("train size:",len(X_train),"\ntest size:",len(X_test))
# Out:
# train size: 1257
# test size: 540

# %%
# 2. learn classifier
knn3= KNeighborsClassifier(n_neighbors=3)
knn30 = KNeighborsClassifier(n_neighbors=30)
gauss=GaussianNB()

knn3.fit(X_train, y_train)
knn30.fit(X_train, y_train)
gauss.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# 3. test classifiers
y_pred3 = knn3.predict(X_test)
y_pred30 = knn30.predict(X_test)
y_predg = gauss.predict(X_test)

acc_knn3 = metrics.accuracy_score(y_test, y_pred3)
acc_knn30 = metrics.accuracy_score(y_test, y_pred30)
acc_gauss = metrics.accuracy_score(y_test, y_predg)

print(f"kNN (k=3) accuracy: {acc_knn3:.2f}")
print(f"kNN (k=30) accuracy: {acc_knn30:.2f}")
print(f"GaussNB accuracy: {acc_gauss:.2f}")
# Out:
# kNN (k=3) accuracy: 0.99
# kNN (k=30) accuracy: 0.95
# GaussNB accuracy: 0.82

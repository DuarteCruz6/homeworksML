# %% [markdown]
# # II - Software Experiments

# %%
import sys
import os
import importlib

#Add code paths
sys.path.append(os.path.abspath("../code/part2/"))

# %% [markdown]
# ## Digits
# Split the data using the command (in the notebook)
# digits = datasets.load_digits()
# X, y = digits.data, digits.target
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,stratify=y,random_state=42)
#
# And do the experiments with kNN with k=3, k=30, and GaussNB (Gaussian Naive Bayes) as
# indicated in the file.
#
# ### a) (0.5 pts) Indicate the accuracy results.

# %%
import digits as d
importlib.reload(d) 

results = d.do(image = False)

print("knn3 accuracy on testing set:",  results[0])
print("knn30 accuracy on testing set:",  results[1])
print("Gauss accuracy on testing set:",  results[2])
# Out:
# train size: 1257
# test size: 540
# knn3 accuracy on testing set: 0.99
# knn30 accuracy on testing set: 0.95
# Gauss accuracy on testing set: 0.82

# %% [markdown]
# ## Wine
#
# Load the wine data set wine = datasets.load_wine()
#
# wine = datasets.load_wine()
# X, y = wine.data, wine.target
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7,stratify=y,random_state=42)
# And do the experiments with kNN with k=3, k=30, and GaussNB.
#
# ### b) (0.5 pts) Indicate the new accuracy values.

# %%
import wine as w
importlib.reload(w) 

results = w.do()

print("knn3 accuracy on testing set:",  results[0])
print("knn30 accuracy on testing set:",  results[1])
print("Gauss accuracy on testing set:",  results[2])
# Out:
# train size: 124
# test size: 54
# knn3 accuracy on testing set: 0.69
# knn30 accuracy on testing set: 0.69
# Gauss accuracy on testing set: 1.0

# %% [markdown]
# ### c ) (1 pts) Which method kNN, k=3,k=30, GaussNB gives better result for which data set?   Do you know why? Please indicate in one/two sentence/s.
#
# k-nearest neighbours -> digits
# gauss -> wine
#
# because....
